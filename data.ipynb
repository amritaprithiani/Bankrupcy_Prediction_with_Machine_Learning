# %%
import pandas as pd
from pathlib import Path
import numpy as np

# %%
df = pd.read_csv(Path("Resources/american_bankruptcy_dataset.csv"))

# %%
df
# Out:
#       company_name status_label    year       X1       X2      X3       X4  \
# 0              C_1        alive  1999.0  511.267  833.107  18.373   89.031
# 1              C_1        alive  2000.0  485.856  713.811  18.577   64.367
# 2              C_1        alive  2001.0  436.656  526.477  22.496   27.207
# 3              C_1        alive  2002.0  396.412  496.747  27.172   30.745
# 4              C_1        alive  2003.0  432.204  523.302  26.680   47.491
# ...            ...          ...     ...      ...      ...     ...      ...
# 78677       C_8971        alive  2014.0  233.211   43.338  14.094   45.615
# 78678       C_8971        alive  2015.0  105.559   59.184  42.592  202.133
# 78679       C_8971        alive  2016.0   63.971   69.074  65.057   79.051
# 78680       C_8971        alive  2017.0  135.207   66.527  65.330   69.171
# 78681       C_8971        alive  2018.0   82.589   68.817  65.201   67.262
#
# ...

# %%
df["status_label"].value_counts()
# Out:
# alive     73462
# failed     5220
# Name: status_label, dtype: int64

# %%
df["status"] = np.where(df["status_label"] == 'alive', 0, 1)

# %%
columns = ["company_name", "status_label", "year", "current_assets", "cost_of_goods_sold", "depreciation_and_amortization", "EBITDA", "inventory", "net_income", "total_receivables", "market_value", "net_sales", "total_assets", "total_long_term_debt", "EBIT", "gross_profit", "total_current_liabilities", "retained_earnings", "total_revenue", "total_liabilities", "total_operationg_expenses", "status"]

# %%
df.columns = columns

# %%
df = df.drop(columns=["company_name", "status_label", "year"])

# %%
df
# Out:
#        current_assets  cost_of_goods_sold  depreciation_and_amortization  \
# 0             511.267             833.107                         18.373
# 1             485.856             713.811                         18.577
# 2             436.656             526.477                         22.496
# 3             396.412             496.747                         27.172
# 4             432.204             523.302                         26.680
# ...               ...                 ...                            ...
# 78677         233.211              43.338                         14.094
# 78678         105.559              59.184                         42.592
# 78679          63.971              69.074                         65.057
# 78680         135.207              66.527                         65.330
# 78681          82.589              68.817                         65.201
#
#         EBITDA  inventory  net_income  total_receivables  market_value  \
# ...

# %%
df.to_csv(Path("Resources/relabeled_data.csv"))

# %%
renamed_df = pd.read_csv(Path("Resources/relabeled_data.csv"), index_col=[0])
renamed_df
# Out:
#        current_assets  cost_of_goods_sold  depreciation_and_amortization  \
# 0             511.267             833.107                         18.373
# 1             485.856             713.811                         18.577
# 2             436.656             526.477                         22.496
# 3             396.412             496.747                         27.172
# 4             432.204             523.302                         26.680
# ...               ...                 ...                            ...
# 78677         233.211              43.338                         14.094
# 78678         105.559              59.184                         42.592
# 78679          63.971              69.074                         65.057
# 78680         135.207              66.527                         65.330
# 78681          82.589              68.817                         65.201
#
#         EBITDA  inventory  net_income  total_receivables  market_value  \
# ...
